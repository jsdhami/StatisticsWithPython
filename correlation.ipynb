# %% [markdown]
# ## Correlation
# - In statistics, correlation is a statistical relationship between two random variables or bivariate data.

# %%
import pandas as pd

df = pd.read_csv('./data/tvObs.csv')
print("data is", df)

# find the correlation between the variables
print("The correlation is\n", df.corr())

# plot graph of X[R1] vs Y[R2] using scatter plot and find the correlation between the variables
import matplotlib.pyplot as plt
import seaborn as sns

plt.scatter(df['R1'], df['R2'])
sns.lmplot(x="R1", y="R2", data=df);
plt.title('Scatter plot of X[R1] vs Y[R2]')
plt.xlabel('Rank by X[R1]')
plt.ylabel('Rank by Y[R2]')


plt.show()
# Out:
# data is    R1  R2
# 0   4   2
# 1   6   3
# 2   3   4
# 3   9   9
# 4   1   5
# 5   5   7
# 6   2   1
# 7   7  10
# 8  10   8
# 9   8   6
# Mean is
#  R1    5.5
# R2    5.5
# dtype: float64
# Median is
#  R1    5.5
# R2    5.5
# dtype: float64
# Mode is
#     R1  R2
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4
# 4   5   5
# 5   6   6
# 6   7   7
# 7   8   8
# 8   9   9
# 9  10  10
# Range is
#  R1    9
# R2    9
# dtype: int64
# Variance is
#  R1    9.166667
# R2    9.166667
# dtype: float64
# Standard deviation is
#  R1    3.02765
# R2    3.02765
# dtype: float64
# Skewness is
#  R1    0.0
# R2    0.0
# dtype: float64
# Kurtosis is
#  R1   -1.2
# R2   -1.2
# dtype: float64
# Q1 is
#  R1    3.25
# R2    3.25
# Name: 0.25, dtype: float64
# The correlation is
#            R1        R2
# R1  1.000000  0.684848
# R2  0.684848  1.000000

# %%
# find mean, median, mode, range, variance, standard deviation, skewness, kurtosis for each column
print("Mean is\n", df.mean())
print("Median is\n", df.median())
print("Mode is\n", df.mode())
print("Range is\n", df.max()-df.min())
print("Variance is\n", df.var())
print("Standard deviation is\n", df.std())
print("Skewness is\n", df.skew())
print("Kurtosis is\n", df.kurt())
# quartiles and IQR
print("Q1 is\n", df.quantile(0.25))
print("Q2 is\n", df.quantile(0.5))
print("Q3 is\n", df.quantile(0.75))
print("IQR is\n", df.quantile(0.75) - df.quantile(0.25))
# Out:
# Mean is
#  R1    5.5
# R2    5.5
# dtype: float64
# Median is
#  R1    5.5
# R2    5.5
# dtype: float64
# Mode is
#     R1  R2
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4
# 4   5   5
# 5   6   6
# 6   7   7
# 7   8   8
# 8   9   9
# 9  10  10
# Range is
#  R1    9
# R2    9
# dtype: int64
# Variance is
#  R1    9.166667
# R2    9.166667
# dtype: float64
# Standard deviation is
#  R1    3.02765
# R2    3.02765
# dtype: float64
# Skewness is
#  R1    0.0
# R2    0.0
# dtype: float64
# Kurtosis is
#  R1   -1.2
# R2   -1.2
# dtype: float64
# Q1 is
#  R1    3.25
# R2    3.25
# Name: 0.25, dtype: float64
# Q2 is
#  R1    5.5
# R2    5.5
# Name: 0.5, dtype: float64
# Q3 is
#  R1    7.75
# R2    7.75
# Name: 0.75, dtype: float64
# IQR is
#  R1    4.5
# R2    4.5
# dtype: float64

# %%
# load the data from the file
examScore = pd.read_csv('./data/examScore.csv')
print(examScore)
# find the correlation between the variables
print(examScore.corr())
# Out:
#     M   E
# 0  57  83
# 1  59  80
# 2  55  77
# 3  57  76
# 4  56  75
# 5  58  78
# 6  57  79
# 7  59  74
# 8  57  79
# 9  57  78
#            M         E
# M   1.000000  0.041697
#  E  0.041697  1.000000
